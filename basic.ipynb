# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\ml\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ml\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imshow, imread
from skimage.color import rgb2hsv
from skimage.color import rgb2gray

# %%
array_1 = np.array([[180, 255],[200, 100]])
imshow(array_1, cmap ='gray')

# %%
array_2 = np.array([[180, 150, 200],[255, 120, 50],[130, 190, 90]])
imshow(array_2, cmap = 'gray')

# %%
array_spectrum = np.array([np.arange(0,255,17),
np.arange(255,0,-17),
np.arange(0,255,17),
np.arange(255,0,-17)])
fig, ax = plt.subplots(1, 2,figsize=(12,4))
ax[0].imshow(array_spectrum, cmap = 'gray')
ax[0].set_title('Arange Generation')
ax[1].imshow(array_spectrum.T, cmap = 'gray')
ax[1].set_title('Transpose Generation');

# %%
array_colors = np.array([[[200,180, 50],
[180, 0, 80],[180, 50, 200]]])
imshow(array_colors);

# %%
flowers = imread('flowers.png')
imshow(flowers);

# %%
flowers.shape
# Out:
# (408, 612, 3)

# %%
fig, ax = plt.subplots(1, 3,
figsize=(6,4),
sharey= True)

ax[0].imshow(flowers[:, 0:130])
ax[0].set_title('Split 1')

ax[1].imshow(flowers[:, 130:260])
ax[1].set_title('Split 2')

ax[2].imshow(flowers[:, 260:390])
ax[2].set_title('Split 3');

# %%
imshow(flowers[95:250, 130:275])

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,4), sharey =
True)
ax[0].imshow(flowers[:,:,0], cmap='Reds')
ax[0].set_title('Red')
ax[1].imshow(flowers[:,:,1],cmap='Greens')
ax[1].set_title('Green')
ax[2].imshow(flowers[:,:,2],cmap='Blues')
ax[2].set_title('Blue');

# %%
doggo_hsv = rgb2hsv(flowers)
fig, ax = plt.subplots(1, 3, figsize=(12,4), sharey = True)
ax[0].imshow(flowers[:,:,0], cmap='hsv')
ax[0].set_title('Hue')
ax[1].imshow(flowers[:,:,1], cmap='gray')
ax[1].set_title('Saturation')
ax[2].imshow(flowers[:,:,2], cmap='gray')
ax[2].set_title('Value');

# %%
from skimage import img_as_uint

# %%
doggo_gray = rgb2gray(doggo)
fig, ax = plt.subplots(1, 5, figsize=(17,6), sharey = True)
ax[0].imshow(doggo_gray, cmap = 'gray')
ax[0].set_title('Grayscale Original')
ax[1].imshow(img_as_uint(doggo_gray > 0.25), cmap = 'gray')
ax[1].set_title('Greater than 0.25')
ax[2].imshow(img_as_uint(doggo_gray > 0.50), cmap = 'gray')
ax[2].set_title('Greater than 0.50') 
ax[3].imshow(img_as_uint(doggo_gray > 0.75), cmap = 'gray')
ax[3].set_title('Greater than 0.75')
ax[4].imshow(img_as_uint(doggo_gray > np.mean(doggo_gray)), cmap = 'gray')
ax[4].set_title('Greater than Mean');
